# %%
n=input()
for i in range(len(n)-1,-1,-1):
    print(n[i],end='')

# %%
a,b=map(int,input().split())
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)

# %%
n=int(input())
print(n&(n-1)==0 and n>0)

# %%
import math
m,n=map(int,input().split())
print(math.floor(m/n))

# %%
import math
m,n=map(int,input().split())
print(math.ceil(m/n))

# %%
n=int(input())
if n==0:
    print('so 0')
elif n%2==0:
    print('even')
else:
    print('odd')

# %%
m,n=map(int,input().split())
if (m<0 and n<0):
    print('yes')
else:
    print('no')

# %%
a=input()
b=input()
print(len(a)>len(b))
# Out:
# 3
# 3
# False

# %%
a=int(input())
b=int(input())
c=int(input())
if (a+b>c) and (b+c>a) and (a+c>b):
    print('YES')
else:
    print('NO')

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
print(max(a,b,c,d))

# %%
a = int(input())
b = int(input())
c = int(input())

if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        print("Tam giac deu")
    elif a == b or b == c or a == c:
        print("Tam giac can")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai tam giac")

# %%
a = int(input())
if (a%4==0 and a%100!=0) or a%400==0:
    print('yes')
else:
    print('no')

# %%
dien=int(input())
if 0<=dien<=50:
    tien=dien*1500
elif 50<dien<=100:
    tien=50*1500+(dien-50)*2000
else:
    tien=50*1500 + 50*2000 + (dien-100)*3000
print(tien)

# %%
a=float(input())
b=float(input())

if a==0 and b==0:
    print('vo so nghiem')
elif b!=0 and a==0:
    print('vo nghiem')
elif b==0 and a!=0:
    print('0')
else:
    print(f"{(-b/a):.2f}")

# %%
n=float(input())
if n>=8:
    print('gioi')
elif n>=6.5:
    print('kha')
elif n>=5:
    print('trung binh')
else:
    print('yeu')

# %%
n=float(input())
if n%1==0:
    print(int(n),int(n),int(n))
else:
    print(int(n//1+1),int(n//1),int(n//1+1) if abs(n-n//1) >0.5  else int(n//1))

# %%
a,b,c=map(int,input().split())

if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        print("Tam giac deu")
    elif a == b or b == c or a == c:
        print("Tam giac can")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai tam giac")
